# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)
    
api_key = '17c351b702fe133b97f4d097617788e6315c2f49'
base_url1 = "https://api.census.gov/data/2018/abscs?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,RCPPDEMP,RCPPDEMP_F,EMP,EMP_F,PAYANN,PAYANN_F,FIRMPDEMP_S,FIRMPDEMP_S_F,RCPPDEMP_S,RCPPDEMP_S_F,EMP_S,EMP_S_F,PAYANN_S,PAYANN_S_F&for=us:*&NAICS2017=00&key="
# base_url2 = "https://api.census.gov/data/2018/abscb?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,QDESC,QDESC_LABEL,BUSCHAR,BUSCHAR_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,FIRMPDEMP_PCT,FIRMPDEMP_PCT_F,RCPPDEMP,RCPPDEMP_F,RCPPDEMP_PCT,RCPPDEMP_PCT_F,EMP,EMP_F,EMP_PCT,EMP_PCT_F,PAYANN,PAYANN_F,PAYANN_PCT,PAYANN_PCT_F,FIRMPDEMP_S,FIRMPDEMP_S_F,FIRMPDEMP_PCT_S,FIRMPDEMP_PCT_S_F,RCPPDEMP_S,RCPPDEMP_S_F,RCPPDEMP_PCT_S,RCPPDEMP_PCT_S_F,EMP_S,EMP_S_F,EMP_PCT_S,EMP_PCT_S_F,PAYANN_S,PAYANN_S_F,PAYANN_PCT_S,PAYANN_PCT_S_F&for=us:*&key="
# base_url3 = "https://api.census.gov/data/2018/abscbo?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,OWNER_SEX,OWNER_SEX_LABEL,OWNER_ETH,OWNER_ETH_LABEL,OWNER_RACE,OWNER_RACE_LABEL,OWNER_VET,OWNER_VET_LABEL,QDESC,QDESC_LABEL,OWNCHAR,OWNCHAR_LABEL,YEAR,OWNPDEMP,OWNPDEMP_F,OWNPDEMP_PCT,OWNPDEMP_PCT_F,OWNPDEMP_S,OWNPDEMP_S_F,OWNPDEMP_PCT_S,OWNPDEMP_PCT_S_F&for=us:*&key="
# base_url4 = "https://api.census.gov/data/2018/abstcb?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,NSFSZFI,NSFSZFI_LABEL,FACTORS_P,FACTORS_P_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,FIRMPDEMP_PCT,FIRMPDEMP_PCT_F,RCPPDEMP,RCPPDEMP_F,RCPPDEMP_PCT,RCPPDEMP_PCT_F,EMP,EMP_F,EMP_PCT,EMP_PCT_F,PAYANN,PAYANN_F,PAYANN_PCT,PAYANN_PCT_F,FIRMPDEMP_S,FIRMPDEMP_S_F,FIRMPDEMP_PCT_S,FIRMPDEMP_PCT_S_F,RCPPDEMP_S,RCPPDEMP_S_F,RCPPDEMP_PCT_S,RCPPDEMP_PCT_S_F,EMP_S,EMP_S_F,EMP_PCT_S,EMP_PCT_S_F,PAYANN_S,PAYANN_S_F,PAYANN_PCT_S,PAYANN_PCT_S_F&for=us:*&key="
complete_url1 = base_url1 + api_key
# complete_url2 = base_url2 + api_key
# complete_url3 = base_url3 + api_key
# complete_url4 = base_url4 + api_key
response1 = requests.get(complete_url1)
# response2 = requests.get(complete_url2)
# response3 = requests.get(complete_url3)
# response4 = requests.get(complete_url4)
data1 = response1.json()
# data2 = response2.json()
# data3 = response3.json()
# data4 = response4.json()
with open('data1.json', 'w') as f:
    json.dump(data1, f)
# with open('data2.json', 'w') as f:
#     json.dump(data2, f)
# with open('data3.json', 'w') as f:
#     json.dump(data3, f)
# with open('data4.json', 'w') as f:
#     json.dump(data4, f)
print('Done')
# Out:
# Done

# %%
df1 = pd.read_json("data1.json")
new_header = df1.loc[0]
df1 = df1[1:]
df1.columns = new_header
df1.info()
df1.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1176 entries, 1 to 1176
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GEO_ID            1176 non-null   object
#  1   NAME              1176 non-null   object
#  2   NAICS2017         1176 non-null   object
#  3   NAICS2017_LABEL   1176 non-null   object
#  4   SEX               1176 non-null   object
#  5   SEX_LABEL         1176 non-null   object
#  6   ETH_GROUP         1176 non-null   object
#  7   ETH_GROUP_LABEL   1176 non-null   object
#  8   RACE_GROUP        1176 non-null   object
#  9   RACE_GROUP_LABEL  1176 non-null   object
#  10  VET_GROUP         1176 non-null   object
#  11  VET_GROUP_LABEL   1176 non-null   object
#  12  EMPSZFI           1176 non-null   object
#  13  EMPSZFI_LABEL     1176 non-null   object
#  14  YEAR              1176 non-null   object
#  15  FIRMPDEMP         1176 non-null   object
# ...

# %%
df1 = df1.drop(['GEO_ID','NAME','NAICS2017','NAICS2017_LABEL','SEX','ETH_GROUP','RACE_GROUP','VET_GROUP',
                'EMPSZFI','EMPSZFI_LABEL','YEAR','FIRMPDEMP','FIRMPDEMP_F','RCPPDEMP','RCPPDEMP_F','PAYANN','PAYANN_F','FIRMPDEMP_S',
                'FIRMPDEMP_S_F','RCPPDEMP_S','RCPPDEMP_S_F','EMP_S_F','PAYANN_S','PAYANN_S_F','NAICS2017','us'], axis = 1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1176 entries, 1 to 1176
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SEX_LABEL         1176 non-null   object
#  1   ETH_GROUP_LABEL   1176 non-null   object
#  2   RACE_GROUP_LABEL  1176 non-null   object
#  3   VET_GROUP_LABEL   1176 non-null   object
#  4   EMP               1176 non-null   object
#  5   EMP_F             216 non-null    object
#  6   EMP_S             1176 non-null   object
# dtypes: object(7)
# memory usage: 64.4+ KB

# %%
sexemp = df1[['SEX_LABEL', 'EMP']]
df1['EMP'] = pd.to_numeric(df1["EMP"])
df1['EMP_S'] = pd.to_numeric(df1["EMP_S"])
placesex = sexemp.groupby(['SEX_LABEL']).sum()
placesex = placesex.sort_values(['EMP'])
placesex.drop(labels = ['Classifiable'], axis = 0, inplace = True)
placesex.drop(labels = ['Total'], axis = 0, inplace = True)
placesex.drop(labels = ['Unclassifiable'], axis = 0, inplace = True)
placesex.drop(labels = ['Equally male/female'], axis = 0, inplace = True)
placesex
# Out:
# 0                EMP
# SEX_LABEL
# Female     132094182
# Male       588903798

# %%
placesexG = placesex.plot.bar(title = 'Employees by Sex', legend = False)
placesexG.set_ylabel('Employees (hundred millions)')
placesexG.set_xlabel('Sex', labelpad=15)
placesexG.bar_label(placesexG.containers[0], fmt = '%d', label_type='center', style='italic')
plt.xticks(rotation=0)
plt.show()

# %%
raceemp = df1[['RACE_GROUP_LABEL', 'EMP']]
df1['EMP'] = pd.to_numeric(df1["EMP"])
placerace = raceemp.groupby(['RACE_GROUP_LABEL']).sum()
placerace = placerace.sort_values(['EMP'])
placerace.drop(labels = ['Classifiable'], axis = 0, inplace = True)
placerace.drop(labels = ['Total'], axis = 0, inplace = True)
placerace.drop(labels = ['Unclassifiable'], axis = 0, inplace = True)
placerace.drop(labels = ['Nonminority'], axis = 0, inplace = True)
placerace.drop(labels = ['Equally minority/nonminority'], axis = 0, inplace = True)
placerace.drop(labels = ['Minority'], axis = 0, inplace = True)
placerace
# Out:
# 0                                                 EMP
# RACE_GROUP_LABEL
# Native Hawaiian and Other Pacific Islander     352587
# American Indian and Alaska Native             2155878
# Black or African American                    12910459
# Asian                                        55793596
# White                                       625070072

# %%
placeraceG = placerace.plot(title = 'Employees by Race', kind = 'barh', legend = False)
placeraceG.set_ylabel('Race')
placeraceG.set_xlabel('Employees (hundred millions)')
placeraceG.bar_label(placeraceG.containers[0], fmt = '%d', style='italic')
plt.show()

# %%
vetemp = df1[['VET_GROUP_LABEL', 'EMP']]
df1['EMP'] = pd.to_numeric(df1["EMP"])
placevet = vetemp.groupby(['VET_GROUP_LABEL']).sum()
placevet = placevet.sort_values(['EMP'])
placevet.drop(labels = ['Classifiable'], axis = 0, inplace = True)
placevet.drop(labels = ['Unclassifiable'], axis = 0, inplace = True)
placevet.drop(labels = ['Total'], axis = 0, inplace = True)
placevet.drop(labels = ['Equally veteran/nonveteran'], axis = 0, inplace = True)
placevet
# Out:
# 0                      EMP
# VET_GROUP_LABEL
# Veteran           47622576
# Nonveteran       756213624

# %%
placevetG = placevet.plot(title = 'Employees by Veteran Status', kind = 'bar', legend = False)
placevetG.set_ylabel('Employees (hundred millions)')
placevetG.set_xlabel('Veteran Status')
placevetG.bar_label(placevetG.containers[0], fmt = '%d', label_type='center', style='italic')
plt.xticks(rotation=0)
plt.show()
