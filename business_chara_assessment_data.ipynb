# %% [markdown]
# ## Calling the Characteristics of Businesses Census Data API

# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

api_key = '17c351b702fe133b97f4d097617788e6315c2f49'
base_url = "https://api.census.gov/data/2018/abscb?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,QDESC,QDESC_LABEL,BUSCHAR,BUSCHAR_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,FIRMPDEMP_PCT,FIRMPDEMP_PCT_F,RCPPDEMP,RCPPDEMP_F,RCPPDEMP_PCT,RCPPDEMP_PCT_F,EMP,EMP_F,EMP_PCT,EMP_PCT_F,PAYANN,PAYANN_F,PAYANN_PCT,PAYANN_PCT_F,FIRMPDEMP_S,FIRMPDEMP_S_F,FIRMPDEMP_PCT_S,FIRMPDEMP_PCT_S_F,RCPPDEMP_S,RCPPDEMP_S_F,RCPPDEMP_PCT_S,RCPPDEMP_PCT_S_F,EMP_S,EMP_S_F,EMP_PCT_S,EMP_PCT_S_F,PAYANN_S,PAYANN_S_F,PAYANN_PCT_S,PAYANN_PCT_S_F&for=us:*&key="
complete_url = base_url + api_key
response = requests.get(complete_url)
data = response.json()
with open('data.json', 'w') as f:
    json.dump(data, f)

df = pd.read_json("data.json")
new_header = df.loc[0]
df = df[1:]
df.columns = new_header
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48737 entries, 1 to 48737
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GEO_ID             48737 non-null  object
#  1   NAME               48737 non-null  object
#  2   NAICS2017          48737 non-null  object
#  3   NAICS2017_LABEL    48737 non-null  object
#  4   SEX                48737 non-null  object
#  5   SEX_LABEL          48737 non-null  object
#  6   ETH_GROUP          48737 non-null  object
#  7   ETH_GROUP_LABEL    48737 non-null  object
#  8   RACE_GROUP         48737 non-null  object
#  9   RACE_GROUP_LABEL   48737 non-null  object
#  10  VET_GROUP          48737 non-null  object
#  11  VET_GROUP_LABEL    48737 non-null  object
#  12  QDESC              48737 non-null  object
#  13  QDESC_LABEL        48737 non-null  object
#  14  BUSCHAR            48737 non-null  object
#  15  BUSCHAR_LABEL      48737 non-null  object
# ...

# %% [markdown]
# # Cleaning the data/Creating visualizations

# %%
#Clean the data to only include necessary columns and drop certain row values
df = df[['NAICS2017_LABEL','RACE_GROUP_LABEL','SEX_LABEL','PAYANN','EMP']]
df = df[~df.RACE_GROUP_LABEL.isin(["Classifiable","Total","Unclassifiable","Nonminority"])]
df = df[~df.SEX_LABEL.isin(["Classifiable","Total","Unclassifiable",])]

#Creates a horizontal bar graph comparing race and annual payroll
    #race_and_payroll = df[['RACE_GROUP_LABEL','PAYANN']]

    #rp = rpclean.groupby('RACE_GROUP_LABEL').median()

    #fig1 = rp.plot.barh(title="Median Annual Payroll by Race with SPOUSES Business Characteristics",legend=False)
    #fig1.set_xlabel("Annual Payroll ($1000)")
    #fig1.set_ylabel("Race")

#Creates a horizontal bar graph comparing race and number of employees
    #race_and_employees = df[['RACE_GROUP_LABEL','EMP']]

    #re = reclean.groupby('RACE_GROUP_LABEL').median()

    #fig2 = rp.plot.barh(title="Median Number of Employees by Race with SPOUSES Business Characteristic",legend=False)
    #fig2.set_xlabel("Number of Employees")
    #fig2.set_ylabel("Race")

#Creates a pie chart showing the gender breakdown of businesses
    #sex_and_employees = df[['SEX_LABEL','EMP']]

    #seclean_vc = seclean.SEX_LABEL.value_counts(normalize=True)

    #fig3 = seclean_vc.plot.pie(title="Businesses with SPOUSES Business Characteristic by Gender",ylabel='Gender',figsize=(5,5))

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4719 entries, 126 to 48284
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NAICS2017_LABEL   4719 non-null   object
#  1   RACE_GROUP_LABEL  4719 non-null   object
#  2   SEX_LABEL         4719 non-null   object
#  3   PAYANN            4719 non-null   object
#  4   EMP               4719 non-null   object
# dtypes: object(5)
# memory usage: 221.2+ KB
